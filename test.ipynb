# %%
from tig20 import TIG20, TIG20Error

# %%
tig = TIG20(port="COM4")
tig.open()

# %%
tig.is_rf_on_set()
# Out:
# False

# %%
tig.rf_on()

# %%
tig.set_contactor(True)

# %%
tig.set_control_mode(1)

# %%
tig.write_setpoint(50)

# %%
tig.rf_off()

# %%
tig.close()
